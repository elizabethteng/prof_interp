# %%
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow.keras import layers, losses, models, optimizers
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error as mse
import matplotlib.pyplot as plt
from matplotlib import rcParams as rc
rc['font.size']=12
import random
from tensorflow import keras
from time import time
# Out:
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /opt/anaconda3/envs/eliz/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
# dataset format:  m1, m2, p, final mass, normalized mass_enc profile,
#  central log(temperature), scaled temperature profile
data1 = np.load("../data/normalized_logrho_profiles.npy",allow_pickle=True)
valid = np.load("../data/normalized_logrho_validation_profiles.npy", allow_pickle=True)
random.seed(10)
data = random.sample(list(data1), 5000)

m1 = np.array([prof.get('m1') for prof in data], dtype='f') # initial stellar mass
m2 = np.array([prof.get('m2') for prof in data], dtype='f')
p = np.array([prof.get('p') for prof in data], dtype='f') # initial orbital period
linear_x = np.array(np.transpose([m1,m2,p]),dtype='f')

x = np.log10(linear_x) # 3d inputs for NN

linear_final_mass = np.array([prof.get('final_mass') for prof in data],dtype="f") # final stellar mass
final_mass = np.log10(linear_final_mass)

rho_min = np.array([prof.get('min_logrho') for prof in data], dtype='f')
rho_max = np.array([prof.get('max_logrho') for prof in data], dtype='f')

mass_points = data[0].get('m_arr') # x-values for normalized profiles

rho_minmax = np.array([[prof.get('min_logrho'), prof.get('max_logrho')] for prof in data], dtype='f')

# scaled density profiles
prof_true = np.array([prof.get('logrho_arr') for prof in data],dtype='f')

# plotting the density data (first 1000)
plt.figure(figsize=(6,6))
for i in range(1000):
    plt.plot(mass_points,prof_true[i],alpha=0.02,c='b')
plt.xlabel("fraction of mass enclosed")
plt.ylabel("log(rho)")
plt.title("density profiles")
plt.show()

# %%
valid_m1 = np.array([prof.get('m1') for prof in valid], dtype='f') # initial stellar mass
valid_m2 = np.array([prof.get('m2') for prof in valid], dtype='f')
valid_p = np.array([prof.get('p') for prof in valid], dtype='f') # initial orbital period
valid_linear_x = np.array(np.transpose([valid_m1,valid_m2,valid_p]),dtype='f')

valid_x = np.log10(valid_linear_x) # 3d inputs for NN

valid_linear_final_mass = np.array([prof.get('final_mass') for prof in valid],dtype="f") # final stellar mass
valid_final_mass = np.log10(valid_linear_final_mass)

valid_rho_min = np.array([prof.get('min_logrho') for prof in valid], dtype='f')
valid_rho_max = np.array([prof.get('max_logrho') for prof in valid], dtype='f')

valid_mass_points = valid[0].get('m_arr') # x-values for normalized profiles

valid_rho_minmax = np.array([[prof.get('min_logrho'), prof.get('max_logrho')] for prof in valid], dtype='f')

# scaled density profiles
valid_prof_true = np.array([prof.get('logrho_arr') for prof in valid],dtype='f')

# %%
# VALIDATION
valid_pca = PCA(n_components=6).fit(valid_prof_true) # training PCA
valid_prof_low_unscaled = valid_pca.transform(valid_prof_true) # PCA weights 

# scaling factor: st dev of each component
valid_sc = np.std(valid_prof_low_unscaled,axis=0)
valid_prof_low = valid_prof_low_unscaled/valid_sc # scaled pca weights: 6-d NN outputs
valid_reconst = valid_pca.inverse_transform(valid_prof_low*valid_sc) # PCA reconstructed data

# plt.figure()
# plt.ylabel('% Variance Explained by PCA')
# plt.xlabel('# of Features')
# plt.title('PCA Variance')
# plt.ylim(86,100)
# plt.plot(np.arange(1,len(valid_pca.components_)+1),\
#          np.cumsum(valid_pca.explained_variance_ratio_)*100)
# plt.grid()

# plt.show()

# colors = plt.cm.viridis(np.linspace(0,1,len(valid_pca.components_)))
# plt.figure()
# for i in range(len(valid_pca.components_)):
#     plt.plot(valid_mass_points,valid_pca.components_[i]+0.2*i,c=colors[i])
# plt.xlabel("fraction of mass enclosed")
# plt.ylabel("log(rho)+offset")
# plt.title("principal components of dataset")
# plt.show()

# plt.figure(figsize=(6,6))
# for i in range(1000):
#     plt.plot(valid_mass_points,valid_prof_true[i],alpha=0.02,c='b')
#     plt.plot(valid_mass_points,valid_reconst[i],alpha=0.02,c='r')
# plt.xlabel("fraction of mass enclosed")
# plt.ylabel("log(rho)")
# plt.title("PCA-reconstructed (red) vs true (blue) density profiles")
# plt.show()

# %% [markdown]
# Next, I reshape and reduce dimensionality of the 200-d temperature profile outputs using PCA sphering. I only use the first 6 principal components, which explain ~99% of the variance between the set of original profiles and their PCA reconstructions (as the plot below shows)

# %%
pca = PCA(n_components=6).fit(prof_true) # training PCA

plt.figure()
plt.ylabel('% Variance Explained by PCA')
plt.xlabel('# of Features')
plt.title('PCA Variance')
plt.ylim(86,100)
plt.plot(np.arange(1,len(pca.components_)+1),\
         np.cumsum(pca.explained_variance_ratio_)*100)
plt.grid()

plt.show()

# colors = plt.cm.viridis(np.linspace(0,1,len(pca.components_)))
# plt.figure()
# for i in range(len(pca.components_)):
#     plt.plot(mass_points,pca.components_[i]+0.2*i,c=colors[i])
# plt.xlabel("fraction of mass enclosed")
# plt.ylabel("log(rho)+offset")
# plt.title("principal components of dataset")
# plt.show()

# %%
prof_low_unscaled = pca.transform(prof_true) # PCA weights 

# scaling factor: st dev of each component
sc = np.std(prof_low_unscaled,axis=0)
prof_low = prof_low_unscaled/sc # scaled pca weights: 6-d NN outputs
reconst = pca.inverse_transform(prof_low*sc) # PCA reconstructed data

# plotting for the first 1000 points out of 38000 because it gets too cluttered
plt.figure(figsize=(6,6))
for i in range(1000):
    plt.plot(mass_points,prof_true[i],alpha=0.02,c='b')
    plt.plot(mass_points,reconst[i],alpha=0.02,c='r')
plt.xlabel("fraction of mass enclosed")
plt.ylabel("log(rho)")
plt.title("PCA-reconstructed (red) vs true (blue) density profiles")
plt.show()

# %%
# Comparing true profiles to reconstructed profiles
# for i in range(30):
#     plt.plot(mass_points,prof_true[i])
#     plt.plot(mass_points, reconst[i])
#     plt.ylabel(i)
#     plt.show()
    
# 12 components gives a nearly identical reconstruction
# 6 components is a bit worse but still good, with slight deviations

# %% [markdown]
# My neural network consists of 6 fully-connected layers, with 2 inputs for the initial stellar mass and initial orbital periods,
# and 6 outputs. I use the Adam optimizer on a mean squared error loss function.

# %%
model = models.Sequential([
    layers.Dense(15,input_dim=3,activation=None),
    layers.Dense(15,input_dim=15,activation="relu"),
    layers.Dense(15,input_dim=15,activation="relu"),
    layers.Dense(15,input_dim=15,activation="tanh"),
    layers.Dense(10,input_dim=10,activation="tanh"),
    layers.Dense(10,input_dim=10,activation="tanh"),
    layers.Dense(6,input_dim=10,activation=None)
])

regress = lambda x: model(x)
# Out:
# 2022-12-05 10:09:33.620556: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-05 10:09:33.621004: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
prof_low_pred = regress(x)
loss_mse = losses.MeanSquaredError()
loss_mse(prof_low,prof_low_pred).numpy()
# Out:
# 1.0430636

# %%
t0 = time()
model.compile(optimizers.Adam(clipnorm=1),loss=loss_mse,lr=0.0001)
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=200)
history = model.fit(x,prof_low,epochs=3000,callbacks=[callback],verbose=0, validation_data=(valid_x, valid_prof_low))
plt.plot(history.history['loss'])
plt.plot(history.history["val_loss"],alpha=0.5)
plt.show()
print("time:",time()-t0)
# Out:
# time: 849.3014540672302

# %%
prof_low_pred = regress(x)
loss_mse = losses.MeanSquaredError()
loss_mse(prof_low,prof_low_pred).numpy()
# Out:
# 0.13843542

# %%
for i in range(6):
    plt.figure()
    low = np.min(valid_prof_low[:,i])
    high = np.max(valid_prof_low[:,i])
    num=29
    plt.hist(valid_prof_low[:,i],alpha=0.5,bins=np.linspace(low, high,num))
    plt.hist(model(valid_x).numpy()[:,i],alpha=0.5,bins=np.linspace(low, high,num))
    plt.show()

# %% [markdown]
# # final mass

# %%
# model to predict final mass - 3 inputs, 1 output
model_mass = models.Sequential([
    layers.Dense(10,input_dim=3,activation=None),
    layers.Dense(10,input_dim=10,activation='relu'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(1,activation=None)
])

regress_mass = lambda x: model_mass(x)


mpred = regress_mass(x)

loss_mse = losses.MeanSquaredError()
loss_mape = losses.MeanAbsolutePercentageError()
loss_mse(final_mass,mpred).numpy()
#loss_mape(final_mass,mpred).numpy()
# Out:
# 0.81622535

# %%
plt.figure()
plt.hist(valid_final_mass,alpha=0.5)
plt.hist(model_mass(valid_x).numpy(),alpha=0.5)
plt.show()

# %%
t0 = time()
model_mass.compile(optimizers.Adam(clipnorm=1),loss=loss_mse,lr=0.001)
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)
history = model_mass.fit(x,final_mass,epochs=2000,\
                         callbacks=[callback],verbose=1,\
                        validation_data =(valid_x,valid_final_mass))
plt.plot(history.history['loss'])
plt.plot(history.history["val_loss"],alpha=0.5)
plt.show()

print("time",time()-t0)
model_mass.evaluate(x,final_mass,verbose=2)
# Out:
# Train on 5000 samples, validate on 2656 samples
# Epoch 1/2000
# 5000/5000 [==============================] - 2s 319us/sample - loss: 0.1721 - val_loss: 0.0275
# Epoch 2/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0190 - val_loss: 0.0186
# Epoch 3/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0147 - val_loss: 0.0169
# Epoch 4/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0130 - val_loss: 0.0158
# Epoch 5/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0122 - val_loss: 0.0142
# Epoch 6/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0121 - val_loss: 0.0131
# Epoch 7/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0113 - val_loss: 0.0132
# Epoch 8/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0114 - val_loss: 0.0130
# Epoch 9/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0111 - val_loss: 0.0123
# Epoch 10/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0107 - val_loss: 0.0135
# Epoch 11/2000
# 5000/5000 [==============================] - 1s 112us/sample - loss: 0.0108 - val_loss: 0.0126
# Epoch 12/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0105 - val_loss: 0.0116
# Epoch 13/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0105 - val_loss: 0.0115
# Epoch 14/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0108 - val_loss: 0.0127
# Epoch 15/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0100 - val_loss: 0.0125
# Epoch 16/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0098 - val_loss: 0.0110
# Epoch 17/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0097 - val_loss: 0.0117
# Epoch 18/2000
# 5000/5000 [==============================] - 1s 113us/sample - loss: 0.0094 - val_loss: 0.0114
# Epoch 19/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0097 - val_loss: 0.0101
# Epoch 20/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0095 - val_loss: 0.0110
# Epoch 21/2000
# 5000/5000 [==============================] - 1s 117us/sample - loss: 0.0094 - val_loss: 0.0109
# Epoch 22/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0096 - val_loss: 0.0126
# Epoch 23/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0094 - val_loss: 0.0112
# Epoch 24/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0095 - val_loss: 0.0107
# Epoch 25/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0094 - val_loss: 0.0112
# Epoch 26/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0091 - val_loss: 0.0108
# Epoch 27/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0089 - val_loss: 0.0104
# Epoch 28/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0088 - val_loss: 0.0090
# Epoch 29/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0085 - val_loss: 0.0108
# Epoch 30/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0089 - val_loss: 0.0105
# Epoch 31/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0090 - val_loss: 0.0098
# Epoch 32/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0084 - val_loss: 0.0101
# Epoch 33/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0091 - val_loss: 0.0090
# Epoch 34/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0084 - val_loss: 0.0101
# Epoch 35/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0084 - val_loss: 0.0102
# Epoch 36/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0084 - val_loss: 0.0084
# Epoch 37/2000
# 5000/5000 [==============================] - 1s 136us/sample - loss: 0.0086 - val_loss: 0.0110
# Epoch 38/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0082 - val_loss: 0.0082
# Epoch 39/2000
# 5000/5000 [==============================] - 1s 119us/sample - loss: 0.0083 - val_loss: 0.0076
# Epoch 40/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0081 - val_loss: 0.0084
# Epoch 41/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0079 - val_loss: 0.0093
# Epoch 42/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0084 - val_loss: 0.0089
# Epoch 43/2000
# 5000/5000 [==============================] - 1s 123us/sample - loss: 0.0075 - val_loss: 0.0078
# Epoch 44/2000
# 5000/5000 [==============================] - 1s 229us/sample - loss: 0.0073 - val_loss: 0.0090
# Epoch 45/2000
# 5000/5000 [==============================] - 1s 177us/sample - loss: 0.0076 - val_loss: 0.0087
# Epoch 46/2000
# 5000/5000 [==============================] - 1s 184us/sample - loss: 0.0080 - val_loss: 0.0077
# Epoch 47/2000
# 5000/5000 [==============================] - 1s 144us/sample - loss: 0.0080 - val_loss: 0.0075
# Epoch 48/2000
# 5000/5000 [==============================] - 1s 150us/sample - loss: 0.0074 - val_loss: 0.0079
# Epoch 49/2000
# 5000/5000 [==============================] - 1s 211us/sample - loss: 0.0072 - val_loss: 0.0073
# Epoch 50/2000
# 5000/5000 [==============================] - 1s 135us/sample - loss: 0.0075 - val_loss: 0.0084
# Epoch 51/2000
# 5000/5000 [==============================] - 1s 125us/sample - loss: 0.0076 - val_loss: 0.0076
# Epoch 52/2000
# 5000/5000 [==============================] - 1s 116us/sample - loss: 0.0069 - val_loss: 0.0089
# Epoch 53/2000
# 5000/5000 [==============================] - 1s 120us/sample - loss: 0.0069 - val_loss: 0.0069
# Epoch 54/2000
# 5000/5000 [==============================] - 1s 120us/sample - loss: 0.0069 - val_loss: 0.0064
# Epoch 55/2000
# 5000/5000 [==============================] - 1s 115us/sample - loss: 0.0070 - val_loss: 0.0076
# Epoch 56/2000
# 5000/5000 [==============================] - 1s 120us/sample - loss: 0.0070 - val_loss: 0.0091
# Epoch 57/2000
# 5000/5000 [==============================] - 1s 127us/sample - loss: 0.0071 - val_loss: 0.0066
# Epoch 58/2000
# 5000/5000 [==============================] - 1s 119us/sample - loss: 0.0076 - val_loss: 0.0070
# Epoch 59/2000
# 5000/5000 [==============================] - 1s 133us/sample - loss: 0.0064 - val_loss: 0.0076
# Epoch 60/2000
# 5000/5000 [==============================] - 1s 117us/sample - loss: 0.0065 - val_loss: 0.0073
# Epoch 61/2000
# 5000/5000 [==============================] - 1s 120us/sample - loss: 0.0074 - val_loss: 0.0069
# Epoch 62/2000
# 5000/5000 [==============================] - 1s 181us/sample - loss: 0.0069 - val_loss: 0.0069
# Epoch 63/2000
# 5000/5000 [==============================] - 1s 139us/sample - loss: 0.0074 - val_loss: 0.0062
# Epoch 64/2000
# 5000/5000 [==============================] - 1s 132us/sample - loss: 0.0064 - val_loss: 0.0067
# Epoch 65/2000
# 5000/5000 [==============================] - 1s 130us/sample - loss: 0.0066 - val_loss: 0.0059
# Epoch 66/2000
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.0062 - val_loss: 0.0068
# Epoch 67/2000
# 5000/5000 [==============================] - 1s 135us/sample - loss: 0.0060 - val_loss: 0.0053
# Epoch 68/2000
# 5000/5000 [==============================] - 1s 166us/sample - loss: 0.0061 - val_loss: 0.0054
# Epoch 69/2000
# 5000/5000 [==============================] - 1s 127us/sample - loss: 0.0061 - val_loss: 0.0055
# Epoch 70/2000
# 5000/5000 [==============================] - 1s 142us/sample - loss: 0.0057 - val_loss: 0.0054
# Epoch 71/2000
# 5000/5000 [==============================] - 1s 150us/sample - loss: 0.0060 - val_loss: 0.0051
# Epoch 72/2000
# 5000/5000 [==============================] - 1s 140us/sample - loss: 0.0056 - val_loss: 0.0050
# Epoch 73/2000
# 5000/5000 [==============================] - 1s 127us/sample - loss: 0.0061 - val_loss: 0.0071
# Epoch 74/2000
# 5000/5000 [==============================] - 1s 132us/sample - loss: 0.0058 - val_loss: 0.0085
# Epoch 75/2000
# 5000/5000 [==============================] - 1s 121us/sample - loss: 0.0061 - val_loss: 0.0060
# Epoch 76/2000
# 5000/5000 [==============================] - 1s 159us/sample - loss: 0.0059 - val_loss: 0.0077
# Epoch 77/2000
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.0058 - val_loss: 0.0064
# Epoch 78/2000
# 5000/5000 [==============================] - 1s 171us/sample - loss: 0.0068 - val_loss: 0.0056
# Epoch 79/2000
# 5000/5000 [==============================] - 1s 201us/sample - loss: 0.0057 - val_loss: 0.0064
# Epoch 80/2000
# 5000/5000 [==============================] - 1s 238us/sample - loss: 0.0067 - val_loss: 0.0058
# Epoch 81/2000
# 5000/5000 [==============================] - 1s 200us/sample - loss: 0.0056 - val_loss: 0.0052
# Epoch 82/2000
# 5000/5000 [==============================] - 1s 172us/sample - loss: 0.0058 - val_loss: 0.0049
# Epoch 83/2000
# 5000/5000 [==============================] - 1s 118us/sample - loss: 0.0057 - val_loss: 0.0066
# Epoch 84/2000
# 5000/5000 [==============================] - 1s 114us/sample - loss: 0.0059 - val_loss: 0.0077
# Epoch 85/2000
# 5000/5000 [==============================] - 1s 114us/sample - loss: 0.0062 - val_loss: 0.0069
# Epoch 86/2000
# 5000/5000 [==============================] - 1s 114us/sample - loss: 0.0053 - val_loss: 0.0080
# Epoch 87/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0059 - val_loss: 0.0051
# Epoch 88/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0060 - val_loss: 0.0049
# Epoch 89/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0059 - val_loss: 0.0049
# Epoch 90/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0054 - val_loss: 0.0059
# Epoch 91/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0054 - val_loss: 0.0073
# Epoch 92/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0050 - val_loss: 0.0048
# Epoch 93/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0056 - val_loss: 0.0045
# Epoch 94/2000
# 5000/5000 [==============================] - 1s 176us/sample - loss: 0.0056 - val_loss: 0.0092
# Epoch 95/2000
# 5000/5000 [==============================] - 1s 216us/sample - loss: 0.0053 - val_loss: 0.0046
# Epoch 96/2000
# 5000/5000 [==============================] - 1s 179us/sample - loss: 0.0058 - val_loss: 0.0043
# Epoch 97/2000
# 5000/5000 [==============================] - 1s 169us/sample - loss: 0.0049 - val_loss: 0.0043
# Epoch 98/2000
# 5000/5000 [==============================] - 1s 215us/sample - loss: 0.0054 - val_loss: 0.0048
# Epoch 99/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0048 - val_loss: 0.0049
# Epoch 100/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0048 - val_loss: 0.0051
# Epoch 101/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0047 - val_loss: 0.0054
# Epoch 102/2000
# 5000/5000 [==============================] - 0s 100us/sample - loss: 0.0055 - val_loss: 0.0067
# Epoch 103/2000
# 5000/5000 [==============================] - 0s 100us/sample - loss: 0.0049 - val_loss: 0.0071
# Epoch 104/2000
# 5000/5000 [==============================] - 1s 114us/sample - loss: 0.0050 - val_loss: 0.0048
# Epoch 105/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0049 - val_loss: 0.0055
# Epoch 106/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0053 - val_loss: 0.0048
# Epoch 107/2000
# 5000/5000 [==============================] - 1s 132us/sample - loss: 0.0044 - val_loss: 0.0044
# Epoch 108/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0044 - val_loss: 0.0080
# Epoch 109/2000
# 5000/5000 [==============================] - 1s 119us/sample - loss: 0.0051 - val_loss: 0.0075
# Epoch 110/2000
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.0045 - val_loss: 0.0045
# Epoch 111/2000
# 5000/5000 [==============================] - 1s 211us/sample - loss: 0.0043 - val_loss: 0.0046
# Epoch 112/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0045 - val_loss: 0.0048
# Epoch 113/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0048 - val_loss: 0.0045
# Epoch 114/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0050 - val_loss: 0.0046
# Epoch 115/2000
# 5000/5000 [==============================] - 1s 180us/sample - loss: 0.0045 - val_loss: 0.0043
# Epoch 116/2000
# 5000/5000 [==============================] - 1s 215us/sample - loss: 0.0038 - val_loss: 0.0061
# Epoch 117/2000
# 5000/5000 [==============================] - 1s 119us/sample - loss: 0.0049 - val_loss: 0.0045
# Epoch 118/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0045 - val_loss: 0.0045
# Epoch 119/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0040 - val_loss: 0.0065
# Epoch 120/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0040 - val_loss: 0.0056
# Epoch 121/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0046 - val_loss: 0.0038
# Epoch 122/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0041 - val_loss: 0.0059
# Epoch 123/2000
# 5000/5000 [==============================] - 1s 123us/sample - loss: 0.0047 - val_loss: 0.0052
# Epoch 124/2000
# 5000/5000 [==============================] - 1s 132us/sample - loss: 0.0049 - val_loss: 0.0040
# Epoch 125/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0038 - val_loss: 0.0049
# Epoch 126/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0041 - val_loss: 0.0043
# Epoch 127/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0039 - val_loss: 0.0043
# Epoch 128/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0037 - val_loss: 0.0043
# Epoch 129/2000
# 5000/5000 [==============================] - 1s 143us/sample - loss: 0.0041 - val_loss: 0.0065
# Epoch 130/2000
# 5000/5000 [==============================] - 1s 141us/sample - loss: 0.0046 - val_loss: 0.0044
# Epoch 131/2000
# 5000/5000 [==============================] - 1s 142us/sample - loss: 0.0039 - val_loss: 0.0032
# Epoch 132/2000
# 5000/5000 [==============================] - 1s 162us/sample - loss: 0.0041 - val_loss: 0.0061
# Epoch 133/2000
# 5000/5000 [==============================] - 1s 189us/sample - loss: 0.0035 - val_loss: 0.0035
# Epoch 134/2000
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.0040 - val_loss: 0.0033
# Epoch 135/2000
# 5000/5000 [==============================] - 1s 120us/sample - loss: 0.0041 - val_loss: 0.0058
# Epoch 136/2000
# 5000/5000 [==============================] - 1s 143us/sample - loss: 0.0046 - val_loss: 0.0033
# Epoch 137/2000
# 5000/5000 [==============================] - 1s 117us/sample - loss: 0.0030 - val_loss: 0.0034
# Epoch 138/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0043 - val_loss: 0.0059
# Epoch 139/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0048 - val_loss: 0.0067
# Epoch 140/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0039 - val_loss: 0.0055
# Epoch 141/2000
# 5000/5000 [==============================] - 1s 179us/sample - loss: 0.0038 - val_loss: 0.0033
# Epoch 142/2000
# 5000/5000 [==============================] - 1s 231us/sample - loss: 0.0030 - val_loss: 0.0041
# Epoch 143/2000
# 5000/5000 [==============================] - 1s 176us/sample - loss: 0.0042 - val_loss: 0.0030
# Epoch 144/2000
# 5000/5000 [==============================] - 1s 121us/sample - loss: 0.0031 - val_loss: 0.0064
# Epoch 145/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0042 - val_loss: 0.0043
# Epoch 146/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0044 - val_loss: 0.0066
# Epoch 147/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0037 - val_loss: 0.0050
# Epoch 148/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0039 - val_loss: 0.0041
# Epoch 149/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0035 - val_loss: 0.0045
# Epoch 150/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0028 - val_loss: 0.0034
# Epoch 151/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0031 - val_loss: 0.0040
# Epoch 152/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0049 - val_loss: 0.0090
# Epoch 153/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0051 - val_loss: 0.0041
# Epoch 154/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0036 - val_loss: 0.0058
# Epoch 155/2000
# 5000/5000 [==============================] - 1s 115us/sample - loss: 0.0040 - val_loss: 0.0035
# Epoch 156/2000
# 5000/5000 [==============================] - 1s 118us/sample - loss: 0.0026 - val_loss: 0.0051
# Epoch 157/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0042 - val_loss: 0.0051
# Epoch 158/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0036 - val_loss: 0.0038
# Epoch 159/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0030 - val_loss: 0.0070
# Epoch 160/2000
# 5000/5000 [==============================] - 1s 115us/sample - loss: 0.0037 - val_loss: 0.0032
# Epoch 161/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0040 - val_loss: 0.0037
# Epoch 162/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0044 - val_loss: 0.0060
# Epoch 163/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0048 - val_loss: 0.0084
# Epoch 164/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0039 - val_loss: 0.0050
# Epoch 165/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0030 - val_loss: 0.0035
# Epoch 166/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0036 - val_loss: 0.0096
# Epoch 167/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0035 - val_loss: 0.0027
# Epoch 168/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0034 - val_loss: 0.0049
# Epoch 169/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0033 - val_loss: 0.0031
# Epoch 170/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0033 - val_loss: 0.0037
# Epoch 171/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0030 - val_loss: 0.0057
# Epoch 172/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0046 - val_loss: 0.0050
# Epoch 173/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0033
# Epoch 174/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0027 - val_loss: 0.0070
# Epoch 175/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0047 - val_loss: 0.0051
# Epoch 176/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0047
# Epoch 177/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0046 - val_loss: 0.0041
# Epoch 178/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0032 - val_loss: 0.0033
# Epoch 179/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0076
# Epoch 180/2000
# 5000/5000 [==============================] - 1s 112us/sample - loss: 0.0035 - val_loss: 0.0036
# Epoch 181/2000
# 5000/5000 [==============================] - 1s 116us/sample - loss: 0.0028 - val_loss: 0.0038
# Epoch 182/2000
# 5000/5000 [==============================] - 1s 118us/sample - loss: 0.0029 - val_loss: 0.0043
# Epoch 183/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0036 - val_loss: 0.0030
# Epoch 184/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0027 - val_loss: 0.0057
# Epoch 185/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0034 - val_loss: 0.0039
# Epoch 186/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0030 - val_loss: 0.0045
# Epoch 187/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0029 - val_loss: 0.0041
# Epoch 188/2000
# 5000/5000 [==============================] - 1s 117us/sample - loss: 0.0031 - val_loss: 0.0048
# Epoch 189/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0032 - val_loss: 0.0048
# Epoch 190/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0047 - val_loss: 0.0042
# Epoch 191/2000
# 5000/5000 [==============================] - 1s 130us/sample - loss: 0.0034 - val_loss: 0.0085
# Epoch 192/2000
# 5000/5000 [==============================] - 1s 140us/sample - loss: 0.0045 - val_loss: 0.0033
# Epoch 193/2000
# 5000/5000 [==============================] - 1s 117us/sample - loss: 0.0031 - val_loss: 0.0050
# Epoch 194/2000
# 5000/5000 [==============================] - 1s 142us/sample - loss: 0.0029 - val_loss: 0.0036
# Epoch 195/2000
# 5000/5000 [==============================] - 1s 122us/sample - loss: 0.0029 - val_loss: 0.0033
# Epoch 196/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0029 - val_loss: 0.0051
# Epoch 197/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0037 - val_loss: 0.0046
# Epoch 198/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0030 - val_loss: 0.0037
# Epoch 199/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0023 - val_loss: 0.0044
# Epoch 200/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0049 - val_loss: 0.0036
# Epoch 201/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0028 - val_loss: 0.0033
# Epoch 202/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0037 - val_loss: 0.0059
# Epoch 203/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0024 - val_loss: 0.0041
# Epoch 204/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0034
# Epoch 205/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0031 - val_loss: 0.0025
# Epoch 206/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0028 - val_loss: 0.0030
# Epoch 207/2000
# 5000/5000 [==============================] - 0s 100us/sample - loss: 0.0038 - val_loss: 0.0051
# Epoch 208/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0039 - val_loss: 0.0033
# Epoch 209/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0032 - val_loss: 0.0031
# Epoch 210/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0029 - val_loss: 0.0040
# Epoch 211/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0023 - val_loss: 0.0053
# Epoch 212/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0032 - val_loss: 0.0041
# Epoch 213/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0036 - val_loss: 0.0031
# Epoch 214/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0032 - val_loss: 0.0035
# Epoch 215/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0025 - val_loss: 0.0034
# Epoch 216/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0028 - val_loss: 0.0024
# Epoch 217/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0030 - val_loss: 0.0030
# Epoch 218/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0036 - val_loss: 0.0027
# Epoch 219/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0033 - val_loss: 0.0064
# Epoch 220/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0039 - val_loss: 0.0030
# Epoch 221/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0031 - val_loss: 0.0041
# Epoch 222/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0025 - val_loss: 0.0044
# Epoch 223/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0037 - val_loss: 0.0044
# Epoch 224/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0041 - val_loss: 0.0045
# Epoch 225/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0038 - val_loss: 0.0040
# Epoch 226/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0024 - val_loss: 0.0029
# Epoch 227/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0029 - val_loss: 0.0035
# Epoch 228/2000
# 5000/5000 [==============================] - 1s 118us/sample - loss: 0.0024 - val_loss: 0.0044
# Epoch 229/2000
# 5000/5000 [==============================] - 1s 137us/sample - loss: 0.0038 - val_loss: 0.0037
# Epoch 230/2000
# 5000/5000 [==============================] - 1s 178us/sample - loss: 0.0031 - val_loss: 0.0067
# Epoch 231/2000
# 5000/5000 [==============================] - 1s 121us/sample - loss: 0.0032 - val_loss: 0.0030
# Epoch 232/2000
# 5000/5000 [==============================] - 1s 118us/sample - loss: 0.0032 - val_loss: 0.0063
# Epoch 233/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 234/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0030 - val_loss: 0.0065
# Epoch 235/2000
# 5000/5000 [==============================] - 1s 129us/sample - loss: 0.0034 - val_loss: 0.0037
# Epoch 236/2000
# 5000/5000 [==============================] - 1s 147us/sample - loss: 0.0025 - val_loss: 0.0028
# Epoch 237/2000
# 5000/5000 [==============================] - 1s 126us/sample - loss: 0.0028 - val_loss: 0.0041
# Epoch 238/2000
# 5000/5000 [==============================] - 1s 164us/sample - loss: 0.0032 - val_loss: 0.0037
# Epoch 239/2000
# 5000/5000 [==============================] - 1s 135us/sample - loss: 0.0036 - val_loss: 0.0025
# Epoch 240/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0027 - val_loss: 0.0051
# Epoch 241/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0033 - val_loss: 0.0033
# Epoch 242/2000
# 5000/5000 [==============================] - 0s 100us/sample - loss: 0.0038 - val_loss: 0.0030
# Epoch 243/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0025 - val_loss: 0.0038
# Epoch 244/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0031 - val_loss: 0.0036
# Epoch 245/2000
# 5000/5000 [==============================] - 1s 148us/sample - loss: 0.0023 - val_loss: 0.0033
# Epoch 246/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0026 - val_loss: 0.0031
# Epoch 247/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0030 - val_loss: 0.0025
# Epoch 248/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0039 - val_loss: 0.0067
# Epoch 249/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0037 - val_loss: 0.0046
# Epoch 250/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0027 - val_loss: 0.0053
# Epoch 251/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0026 - val_loss: 0.0031
# Epoch 252/2000
# 5000/5000 [==============================] - 1s 111us/sample - loss: 0.0020 - val_loss: 0.0043
# Epoch 253/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0024 - val_loss: 0.0026
# Epoch 254/2000
# 5000/5000 [==============================] - 0s 100us/sample - loss: 0.0039 - val_loss: 0.0033
# Epoch 255/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0030 - val_loss: 0.0061
# Epoch 256/2000
# 5000/5000 [==============================] - 0s 100us/sample - loss: 0.0034 - val_loss: 0.0026
# Epoch 257/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0034 - val_loss: 0.0062
# Epoch 258/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0039 - val_loss: 0.0034
# Epoch 259/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0023
# Epoch 260/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0018 - val_loss: 0.0039
# Epoch 261/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0027 - val_loss: 0.0055
# Epoch 262/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0027
# Epoch 263/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0043
# Epoch 264/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0037
# Epoch 265/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0042
# Epoch 266/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0042 - val_loss: 0.0070
# Epoch 267/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0029 - val_loss: 0.0044
# Epoch 268/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0040 - val_loss: 0.0027
# Epoch 269/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0027
# Epoch 270/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0018 - val_loss: 0.0031
# Epoch 271/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 272/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0042 - val_loss: 0.0040
# Epoch 273/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0024 - val_loss: 0.0024
# Epoch 274/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0025 - val_loss: 0.0026
# Epoch 275/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0050
# Epoch 276/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0032 - val_loss: 0.0074
# Epoch 277/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0048
# Epoch 278/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0027 - val_loss: 0.0061
# Epoch 279/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0033
# Epoch 280/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0043 - val_loss: 0.0068
# Epoch 281/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0044 - val_loss: 0.0052
# Epoch 282/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0033 - val_loss: 0.0021
# Epoch 283/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0023
# Epoch 284/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0046
# Epoch 285/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0043 - val_loss: 0.0054
# Epoch 286/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0031 - val_loss: 0.0048
# Epoch 287/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0078
# Epoch 288/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0027 - val_loss: 0.0046
# Epoch 289/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0028 - val_loss: 0.0042
# Epoch 290/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0027 - val_loss: 0.0038
# Epoch 291/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0041 - val_loss: 0.0044
# Epoch 292/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0049
# Epoch 293/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0027 - val_loss: 0.0026
# Epoch 294/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0027
# Epoch 295/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0022 - val_loss: 0.0035
# Epoch 296/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0020 - val_loss: 0.0028
# Epoch 297/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0027 - val_loss: 0.0039
# Epoch 298/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0030 - val_loss: 0.0078
# Epoch 299/2000
# 5000/5000 [==============================] - 1s 108us/sample - loss: 0.0040 - val_loss: 0.0051
# Epoch 300/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0034
# Epoch 301/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0046
# Epoch 302/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0034
# Epoch 303/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0028 - val_loss: 0.0029
# Epoch 304/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0027
# Epoch 305/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0038
# Epoch 306/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0048
# Epoch 307/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0030 - val_loss: 0.0030
# Epoch 308/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0034
# Epoch 309/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0043
# Epoch 310/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0053
# Epoch 311/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0056
# Epoch 312/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0049
# Epoch 313/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0028 - val_loss: 0.0042
# Epoch 314/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 315/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0029
# Epoch 316/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0028
# Epoch 317/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0020 - val_loss: 0.0027
# Epoch 318/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0038 - val_loss: 0.0029
# Epoch 319/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0029
# Epoch 320/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0025
# Epoch 321/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0019 - val_loss: 0.0032
# Epoch 322/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0033 - val_loss: 0.0030
# Epoch 323/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0024 - val_loss: 0.0045
# Epoch 324/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0029 - val_loss: 0.0042
# Epoch 325/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0029 - val_loss: 0.0049
# Epoch 326/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0036 - val_loss: 0.0045
# Epoch 327/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0054
# Epoch 328/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0042
# Epoch 329/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 330/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0025
# Epoch 331/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0040 - val_loss: 0.0030
# Epoch 332/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0020 - val_loss: 0.0032
# Epoch 333/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0018 - val_loss: 0.0028
# Epoch 334/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0027 - val_loss: 0.0060
# Epoch 335/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0026
# Epoch 336/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0044
# Epoch 337/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0030 - val_loss: 0.0032
# Epoch 338/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0039 - val_loss: 0.0037
# Epoch 339/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0023 - val_loss: 0.0043
# Epoch 340/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0028 - val_loss: 0.0068
# Epoch 341/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0035
# Epoch 342/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0027 - val_loss: 0.0024
# Epoch 343/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0021 - val_loss: 0.0025
# Epoch 344/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0028 - val_loss: 0.0038
# Epoch 345/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0064
# Epoch 346/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0026
# Epoch 347/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0021 - val_loss: 0.0022
# Epoch 348/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0060 - val_loss: 0.0032
# Epoch 349/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0032
# Epoch 350/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0019 - val_loss: 0.0027
# Epoch 351/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0024 - val_loss: 0.0050
# Epoch 352/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0044
# Epoch 353/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0047
# Epoch 354/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0018 - val_loss: 0.0031
# Epoch 355/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0025 - val_loss: 0.0039
# Epoch 356/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0027 - val_loss: 0.0042
# Epoch 357/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0030
# Epoch 358/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0024 - val_loss: 0.0033
# Epoch 359/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0020 - val_loss: 0.0026
# Epoch 360/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0035 - val_loss: 0.0021
# Epoch 361/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0027 - val_loss: 0.0030
# Epoch 362/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0052
# Epoch 363/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0032
# Epoch 364/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0019 - val_loss: 0.0022
# Epoch 365/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0051 - val_loss: 0.0023
# Epoch 366/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0019 - val_loss: 0.0029
# Epoch 367/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0018 - val_loss: 0.0024
# Epoch 368/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0021 - val_loss: 0.0047
# Epoch 369/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0019 - val_loss: 0.0071
# Epoch 370/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0032
# Epoch 371/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0016 - val_loss: 0.0024
# Epoch 372/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0084 - val_loss: 0.0089
# Epoch 373/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0065 - val_loss: 0.0075
# Epoch 374/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0058 - val_loss: 0.0076
# Epoch 375/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0051 - val_loss: 0.0059
# Epoch 376/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0047 - val_loss: 0.0056
# Epoch 377/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0041 - val_loss: 0.0086
# Epoch 378/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0042 - val_loss: 0.0056
# Epoch 379/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0033 - val_loss: 0.0039
# Epoch 380/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0037 - val_loss: 0.0050
# Epoch 381/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0034 - val_loss: 0.0034
# Epoch 382/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0049
# Epoch 383/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0052
# Epoch 384/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0028
# Epoch 385/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0032 - val_loss: 0.0036
# Epoch 386/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0031
# Epoch 387/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0028 - val_loss: 0.0033
# Epoch 388/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0032 - val_loss: 0.0043
# Epoch 389/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0031
# Epoch 390/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0029
# Epoch 391/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0032 - val_loss: 0.0035
# Epoch 392/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0030
# Epoch 393/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0028
# Epoch 394/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0025 - val_loss: 0.0042
# Epoch 395/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0042
# Epoch 396/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0026 - val_loss: 0.0040
# Epoch 397/2000
# 5000/5000 [==============================] - 1s 112us/sample - loss: 0.0028 - val_loss: 0.0031
# Epoch 398/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0028 - val_loss: 0.0040
# Epoch 399/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0030
# Epoch 400/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0025 - val_loss: 0.0034
# Epoch 401/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0026
# Epoch 402/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0027 - val_loss: 0.0029
# Epoch 403/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0034
# Epoch 404/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0041 - val_loss: 0.0035
# Epoch 405/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0028 - val_loss: 0.0029
# Epoch 406/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0020 - val_loss: 0.0052
# Epoch 407/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0034 - val_loss: 0.0040
# Epoch 408/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0032
# Epoch 409/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0033 - val_loss: 0.0058
# Epoch 410/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0030
# Epoch 411/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0041
# Epoch 412/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0027 - val_loss: 0.0029
# Epoch 413/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0027 - val_loss: 0.0050
# Epoch 414/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0028 - val_loss: 0.0032
# Epoch 415/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0048
# Epoch 416/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0037 - val_loss: 0.0037
# Epoch 417/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0026 - val_loss: 0.0034
# Epoch 418/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0032
# Epoch 419/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0030 - val_loss: 0.0040
# Epoch 420/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0022 - val_loss: 0.0045
# Epoch 421/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0022 - val_loss: 0.0042
# Epoch 422/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0034
# Epoch 423/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0025
# Epoch 424/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0031
# Epoch 425/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0024 - val_loss: 0.0034
# Epoch 426/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0027 - val_loss: 0.0034
# Epoch 427/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0042 - val_loss: 0.0028
# Epoch 428/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0045
# Epoch 429/2000
# 5000/5000 [==============================] - 1s 109us/sample - loss: 0.0026 - val_loss: 0.0029
# Epoch 430/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0024 - val_loss: 0.0042
# Epoch 431/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0032 - val_loss: 0.0025
# Epoch 432/2000
# 5000/5000 [==============================] - 1s 135us/sample - loss: 0.0027 - val_loss: 0.0043
# Epoch 433/2000
# 5000/5000 [==============================] - 1s 118us/sample - loss: 0.0026 - val_loss: 0.0046
# Epoch 434/2000
# 5000/5000 [==============================] - 1s 119us/sample - loss: 0.0026 - val_loss: 0.0035
# Epoch 435/2000
# 5000/5000 [==============================] - 1s 130us/sample - loss: 0.0024 - val_loss: 0.0037
# Epoch 436/2000
# 5000/5000 [==============================] - 1s 130us/sample - loss: 0.0021 - val_loss: 0.0026
# Epoch 437/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0042 - val_loss: 0.0028
# Epoch 438/2000
# 5000/5000 [==============================] - 1s 110us/sample - loss: 0.0020 - val_loss: 0.0027
# Epoch 439/2000
# ...
# Epoch 1233/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0020 - val_loss: 0.0078
# Epoch 1234/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0037 - val_loss: 0.0050
# Epoch 1235/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0028 - val_loss: 0.0047
# Epoch 1236/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0023 - val_loss: 0.0032
# Epoch 1237/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0024
# Epoch 1238/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0017 - val_loss: 0.0030
# Epoch 1239/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0025
# Epoch 1240/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0018 - val_loss: 0.0030
# Epoch 1241/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0025
# Epoch 1242/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0017 - val_loss: 0.0024
# Epoch 1243/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0023
# Epoch 1244/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0017 - val_loss: 0.0025
# Epoch 1245/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0017 - val_loss: 0.0033
# Epoch 1246/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0021
# Epoch 1247/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0015 - val_loss: 0.0025
# Epoch 1248/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0017 - val_loss: 0.0036
# Epoch 1249/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0076 - val_loss: 0.0074
# Epoch 1250/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0051 - val_loss: 0.0063
# Epoch 1251/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0039 - val_loss: 0.0038
# Epoch 1252/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0032 - val_loss: 0.0033
# Epoch 1253/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0021 - val_loss: 0.0030
# Epoch 1254/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0020 - val_loss: 0.0033
# Epoch 1255/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0018 - val_loss: 0.0029
# Epoch 1256/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0018 - val_loss: 0.0022
# Epoch 1257/2000
# 5000/5000 [==============================] - 1s 105us/sample - loss: 0.0016 - val_loss: 0.0024
# Epoch 1258/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0016 - val_loss: 0.0023
# Epoch 1259/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0023
# Epoch 1260/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0023
# Epoch 1261/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0014 - val_loss: 0.0033
# Epoch 1262/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0013 - val_loss: 0.0021
# Epoch 1263/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0024
# Epoch 1264/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0024
# Epoch 1265/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0016 - val_loss: 0.0034
# Epoch 1266/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0021
# Epoch 1267/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0031
# Epoch 1268/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0016 - val_loss: 0.0024
# Epoch 1269/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0022
# Epoch 1270/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0020
# Epoch 1271/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0040
# Epoch 1272/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0026
# Epoch 1273/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0026
# Epoch 1274/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0074
# Epoch 1275/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0079 - val_loss: 0.0068
# Epoch 1276/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0047 - val_loss: 0.0046
# Epoch 1277/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0040 - val_loss: 0.0039
# Epoch 1278/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0036 - val_loss: 0.0060
# Epoch 1279/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0038 - val_loss: 0.0066
# Epoch 1280/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0035 - val_loss: 0.0044
# Epoch 1281/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0039 - val_loss: 0.0077
# Epoch 1282/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0034 - val_loss: 0.0042
# Epoch 1283/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0032 - val_loss: 0.0040
# Epoch 1284/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0034 - val_loss: 0.0047
# Epoch 1285/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0031 - val_loss: 0.0036
# Epoch 1286/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0030 - val_loss: 0.0064
# Epoch 1287/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0033 - val_loss: 0.0045
# Epoch 1288/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0038
# Epoch 1289/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0033 - val_loss: 0.0046
# Epoch 1290/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0030 - val_loss: 0.0041
# Epoch 1291/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0034 - val_loss: 0.0059
# Epoch 1292/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0026 - val_loss: 0.0037
# Epoch 1293/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0035 - val_loss: 0.0061
# Epoch 1294/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0026 - val_loss: 0.0037
# Epoch 1295/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0033
# Epoch 1296/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0026 - val_loss: 0.0030
# Epoch 1297/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0032
# Epoch 1298/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0022 - val_loss: 0.0036
# Epoch 1299/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0039
# Epoch 1300/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0030 - val_loss: 0.0033
# Epoch 1301/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 1302/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0035
# Epoch 1303/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0030
# Epoch 1304/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0026 - val_loss: 0.0040
# Epoch 1305/2000
# 5000/5000 [==============================] - 1s 107us/sample - loss: 0.0024 - val_loss: 0.0029
# Epoch 1306/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0029 - val_loss: 0.0034
# Epoch 1307/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 1308/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0021 - val_loss: 0.0031
# Epoch 1309/2000
# 5000/5000 [==============================] - 1s 104us/sample - loss: 0.0027 - val_loss: 0.0037
# Epoch 1310/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0032 - val_loss: 0.0039
# Epoch 1311/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0057
# Epoch 1312/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0028 - val_loss: 0.0039
# Epoch 1313/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0041
# Epoch 1314/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0024 - val_loss: 0.0031
# Epoch 1315/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0025 - val_loss: 0.0024
# Epoch 1316/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0026
# Epoch 1317/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0017 - val_loss: 0.0023
# Epoch 1318/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0024
# Epoch 1319/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0017 - val_loss: 0.0025
# Epoch 1320/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0025
# Epoch 1321/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0027 - val_loss: 0.0073
# Epoch 1322/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0052 - val_loss: 0.0034
# Epoch 1323/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0023 - val_loss: 0.0044
# Epoch 1324/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0022 - val_loss: 0.0029
# Epoch 1325/2000
# 5000/5000 [==============================] - 1s 106us/sample - loss: 0.0025 - val_loss: 0.0028
# Epoch 1326/2000
# 5000/5000 [==============================] - 1s 113us/sample - loss: 0.0020 - val_loss: 0.0030
# Epoch 1327/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0016 - val_loss: 0.0026
# Epoch 1328/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0019 - val_loss: 0.0029
# Epoch 1329/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0017 - val_loss: 0.0030
# Epoch 1330/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0015 - val_loss: 0.0030
# Epoch 1331/2000
# 5000/5000 [==============================] - 1s 115us/sample - loss: 0.0017 - val_loss: 0.0034
# Epoch 1332/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0017 - val_loss: 0.0028
# Epoch 1333/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0015 - val_loss: 0.0022
# Epoch 1334/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0023 - val_loss: 0.0035
# Epoch 1335/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0036 - val_loss: 0.0068
# Epoch 1336/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0040 - val_loss: 0.0031
# Epoch 1337/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0019 - val_loss: 0.0028
# Epoch 1338/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0016 - val_loss: 0.0023
# Epoch 1339/2000
# 5000/5000 [==============================] - 1s 101us/sample - loss: 0.0016 - val_loss: 0.0024
# Epoch 1340/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0016 - val_loss: 0.0026
# Epoch 1341/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0018 - val_loss: 0.0061
# Epoch 1342/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0026 - val_loss: 0.0037
# Epoch 1343/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0017 - val_loss: 0.0032
# Epoch 1344/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 1345/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0031
# Epoch 1346/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0015 - val_loss: 0.0030
# Epoch 1347/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0023
# Epoch 1348/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0016 - val_loss: 0.0034
# Epoch 1349/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0018 - val_loss: 0.0018
# Epoch 1350/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0012 - val_loss: 0.0020
# Epoch 1351/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0014 - val_loss: 0.0027
# Epoch 1352/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0015 - val_loss: 0.0055
# Epoch 1353/2000
# 5000/5000 [==============================] - 0s 98us/sample - loss: 0.0028 - val_loss: 0.0030
# Epoch 1354/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0019 - val_loss: 0.0025
# Epoch 1355/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0013 - val_loss: 0.0021
# Epoch 1356/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0012 - val_loss: 0.0027
# Epoch 1357/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0011 - val_loss: 0.0034
# Epoch 1358/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0013 - val_loss: 0.0028
# Epoch 1359/2000
# 5000/5000 [==============================] - 1s 103us/sample - loss: 0.0019 - val_loss: 0.0066
# Epoch 1360/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0036 - val_loss: 0.0038
# Epoch 1361/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0016 - val_loss: 0.0019
# Epoch 1362/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0012 - val_loss: 0.0030
# Epoch 1363/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0016 - val_loss: 0.0020
# Epoch 1364/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0042 - val_loss: 0.0057
# Epoch 1365/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0020 - val_loss: 0.0045
# Epoch 1366/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0020 - val_loss: 0.0026
# Epoch 1367/2000
# 5000/5000 [==============================] - 0s 96us/sample - loss: 0.0013 - val_loss: 0.0022
# Epoch 1368/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0011 - val_loss: 0.0023
# Epoch 1369/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0012 - val_loss: 0.0028
# Epoch 1370/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0013 - val_loss: 0.0025
# Epoch 1371/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0012 - val_loss: 0.0021
# Epoch 1372/2000
# 5000/5000 [==============================] - 1s 102us/sample - loss: 0.0011 - val_loss: 0.0020
# Epoch 1373/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0055 - val_loss: 0.0052
# Epoch 1374/2000
# 5000/5000 [==============================] - 1s 100us/sample - loss: 0.0027 - val_loss: 0.0024
# Epoch 1375/2000
# 5000/5000 [==============================] - 0s 97us/sample - loss: 0.0022 - val_loss: 0.0025
# Epoch 1376/2000
# 5000/5000 [==============================] - 0s 99us/sample - loss: 0.0014 - val_loss: 0.0028
# 5000/1 - 0s - loss: 6.8001e-04
# time 748.1875307559967

# %%
model_mass.evaluate(x,final_mass,verbose=2)
# Out:
# 5000/1 - 0s - loss: 6.8001e-04
# 0.0012984879049705341

# %%
plt.hist(valid_final_mass,alpha=0.5,bins=10)
plt.hist(model_mass(valid_x).numpy(),alpha=0.5,bins=10)
plt.show()

# %% [markdown]
# # min/max density

# %%
# 3 inputs and 2 outputs (min/max logrho)
model_rho = models.Sequential([
    layers.Dense(10,input_dim=3,activation='relu'),
    layers.Dense(10,input_dim=10,activation='relu'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(10,input_dim=10,activation='tanh'),
    layers.Dense(2,activation=None)
])

regress_rho = lambda x: model_rho(x)

rhopred = regress_rho(x)

loss_mse = losses.MeanSquaredError()
loss_mse(rho_minmax,rhopred).numpy()
# Out:
# 40.93567

# %%
t0 = time()
model_rho.compile(optimizers.Adam(clipnorm=1),loss="mse")
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=40)
history = model_rho.fit(x,rho_minmax,epochs=2000,\
                         callbacks=[callback],verbose=0,
                       validation_data =(valid_x,valid_rho_minmax))
plt.plot(history.history['loss'])
plt.plot(history.history["val_loss"],alpha=0.5)
plt.show()

model_rho.evaluate(x,rho_minmax,verbose=2)
print("time:",time()-t0)
# Out:
# 5000/1 - 0s - loss: 0.0255
# time: 219.65992403030396

# %% [markdown]
# # profile predictions
#
# My final prediction brings together all 3 NNs to reconstruct the temperature profile prediction for any new binary in this 2d slice of parameter space.

# %%
def pred_profiles(lin_x):
    x = np.log10(lin_x)
    final_log_masses = regress_mass(x).numpy()
    final_linear_masses = 10**final_log_masses
    
    min_rho = np.array(regress_rho(x)[:,0])
    max_rho = np.array(regress_rho(x)[:,1])
    
    scaled_pca_weights = regress(x)
    norm_profiles = pca.inverse_transform(scaled_pca_weights*sc)
    
    density_profiles = norm_profiles*(max_rho[:,np.newaxis]-min_rho[:,np.newaxis]) + min_rho[:,np.newaxis]
    xcoords = mass_points*final_linear_masses[:,np.newaxis]

    return xcoords,density_profiles

# %%
def eval_model(i):
    testpts = [valid_linear_x[i]]
    xcoords, profiles = pred_profiles(testpts)
    
    true_x = mass_points*valid_linear_final_mass[i]
    true_y = valid_prof_true[i]*(valid_rho_max[i]-valid_rho_min[i])+valid_rho_min[i]
    
    plt.figure(figsize=(9,7))
    plt.plot(true_x, true_y, label="true")
    plt.plot(xcoords[0][0],profiles[0],label="pred")
    plt.xlabel("mass enclosed, solar masses")
    plt.ylabel("predicted log(rho profile)")
    plt.title("NN-predicted density profiles for validation profile "+str(i))
    plt.legend()
    plt.show()

# %%
# mse
for i in [2,3,100,200,300,350,351,2000]:
    print(i)
    eval_model(i)
# Out:
# 2
# 3
# 100
# 200
# 300
# 350
# 351
# 2000

# %% [markdown]
# ## next steps
#
# model evaluation
#
# compare different predictions a la Monica
#
# ask which profiles are most important
#
# temperature
#
# more infrastructure
#
# isolated networks plus one network for correlations
#
# fine tune final mass model

# %%
# mape
for i in [2,3,100,200,300,350,351,2000]:
    print(i)
    eval_model(i)
# Out:
# 2
# 3
# 100
# 200
# 300
# 350
# 351
# 2000
